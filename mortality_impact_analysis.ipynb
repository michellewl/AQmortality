# %% [markdown]
# # Imports

# %%
from data_classes import LAQNData, HealthData, MetData, IncomeData
from os import path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from statsmodels.api import tsa

# %% [markdown]
# # Load data

# %% [markdown]
# ### Load the hourly NO$_2$ data

# %%
species = "NO2"
region = "London"
NO2 = LAQNData(species, region)

# %% [markdown]
# ### Load the hourly meteorology data

# %%
heathrow = MetData("Heathrow")

# %% [markdown]
# ### Load the daily disposable income data

# %%
income = IncomeData()

# %% [markdown]
# ### Load the daily mortality per capita data

# %%
mortality = HealthData()

# %%
mortality_df = mortality.read("mortality-scaled")
mortality_df["deaths_per_100k"] = mortality_df["deaths"]*100000
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: michellewl (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">desert-shape-266</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/michellewl/AQmortality" target="_blank">https://wandb.ai/michellewl/AQmortality</a><br/>
#                 Run page: <a href="https://wandb.ai/michellewl/AQmortality/runs/hmfy681y" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/hmfy681y</a><br/>
#                 Run data is saved locally in <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110720-hmfy681y</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 159<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110720-hmfy681y/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110720-hmfy681y/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">desert-shape-266</strong>: <a href="https://wandb.ai/michellewl/AQmortality/runs/hmfy681y" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/hmfy681y</a><br/>

# %%
mortality_df.shape
# Out:
# (13698, 2)

# %% [markdown]
# # Process data + plots

# %% [markdown]
# ## Daily data

# %%
daily_dates = mortality_df.index

# %% [markdown]
# ### Resample the hourly NO$_2$ data using a custom date list

# %% [markdown]
# Only retain the NO$_2$ data up to the final mortality datapoint:

# %%
#daily_NO2_df = NO2.resample_time_and_log(daily_dates)

# %%
#daily_NO2_df = NO2.read("laqn-resample")

# %%
#daily_NO2_df.shape

# %% [markdown]
# ### Spatially average the NO$_2$ data for all of London

# %%
#NO2_df = NO2.regional_average_and_log()

# %%
NO2_df = NO2.read("laqn-regional")
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">dashing-pyramid-268</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/michellewl/AQmortality" target="_blank">https://wandb.ai/michellewl/AQmortality</a><br/>
#                 Run page: <a href="https://wandb.ai/michellewl/AQmortality/runs/207a7pc3" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/207a7pc3</a><br/>
#                 Run data is saved locally in <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110855-207a7pc3</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 299<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110855-207a7pc3/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_110855-207a7pc3/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">dashing-pyramid-268</strong>: <a href="https://wandb.ai/michellewl/AQmortality/runs/207a7pc3" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/207a7pc3</a><br/>

# %%
NO2_df.shape
# Out:
# (8401, 1)

# %%
NO2_df.index.min()
# Out:
# Timestamp('1996-01-01 00:00:00')

# %% [markdown]
# #### Scatter plot mortality vs NO$_2$

# %%
NO2_df = NO2_df.join(mortality_df)

# %%
plt.figure(figsize=(5,4), dpi=300)
plt.hexbin(NO2_df.mean_NO2, NO2_df.deaths_per_100k, cmap=cm.plasma, gridsize=70, mincnt=1)
plt.ylabel("daily deaths per 100,000")
plt.xlabel("mean daily NO$_2$ (µg m$^{-3}$)")
plt.title("London mortality vs daily NO$_2$")
plt.colorbar().set_label("counts")
plt.show()

# %% [markdown]
# ### Resample the hourly meteorology data using a custom date list

# %% [markdown]
# Only retain the met data up to the final mortality datapoint:

# %%
#daily_met_df = heathrow.resample_time_and_log(daily_dates)
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">bright-forest-273</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/michellewl/AQmortality" target="_blank">https://wandb.ai/michellewl/AQmortality</a><br/>
#                 Run page: <a href="https://wandb.ai/michellewl/AQmortality/runs/n2641eil" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/n2641eil</a><br/>
#                 Run data is saved locally in <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_115015-n2641eil</code><br/><br/>
# wandb: Downloading large artifact met-raw:latest, 130.92MB. 8 files... Done. 0:0:0
# <br/>Waiting for W&B process to finish, PID 717<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_115015-n2641eil/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_115015-n2641eil/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">bright-forest-273</strong>: <a href="https://wandb.ai/michellewl/AQmortality/runs/n2641eil" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/n2641eil</a><br/>

# %%
daily_met_df = heathrow.read(["temperature"], "met-resample")
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">distinctive-star-269</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/michellewl/AQmortality" target="_blank">https://wandb.ai/michellewl/AQmortality</a><br/>
#                 Run page: <a href="https://wandb.ai/michellewl/AQmortality/runs/1lbtcvaz" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/1lbtcvaz</a><br/>
#                 Run data is saved locally in <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112745-1lbtcvaz</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 376<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.0, max=1.0)…
# Find user logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112745-1lbtcvaz/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112745-1lbtcvaz/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">distinctive-star-269</strong>: <a href="https://wandb.ai/michellewl/AQmortality/runs/1lbtcvaz" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/1lbtcvaz</a><br/>

# %%
daily_met_df.shape
# Out:
# (13694, 1)

# %%
temperature_df = pd.DataFrame(daily_met_df["temperature"]).join(mortality_df)

# %% [markdown]
# #### Scatter plot of mortality vs temperature

# %%
plt.figure(figsize=(5,4), dpi=300)
plt.hexbin(temperature_df.temperature, temperature_df.deaths_per_100k, cmap=cm.plasma, gridsize=70, mincnt=1)
plt.ylabel("daily deaths per 100,000")
plt.xlabel("mean daily temperature (℃)")
plt.title("London mortality vs daily temperature")
plt.colorbar().set_label("counts")
plt.show()

# %% [markdown]
# ### Scatter plot of NO$_2$ vs temperature

# %% [markdown]
# #### Daily averages

# %%
daily_df = pd.DataFrame(NO2_df["mean_NO2"]).join(temperature_df)

# %%
daily_df.columns
# Out:
# Index(['mean_NO2', 'temperature', 'deaths', 'deaths_per_100k'], dtype='object')

# %%
plt.figure(figsize=(5,4), dpi=300)
plt.hexbin(daily_df.temperature, daily_df.mean_NO2, cmap=cm.plasma, gridsize=70, mincnt=1)
plt.ylabel("mean daily NO$_2$ (µg m$^{-3}$)")
plt.xlabel("mean daily temperature (℃)")
plt.title("London daily NO$_2$ vs temperature")
plt.colorbar().set_label("counts")
plt.show()

# %% [markdown]
# ### Spatially average the disposable income data for all of London

# %%
#income_df = income.regional_average_and_log()

# %%
income_df = income.read("income-regional")
# Out:
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">legendary-water-270</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/michellewl/AQmortality" target="_blank">https://wandb.ai/michellewl/AQmortality</a><br/>
#                 Run page: <a href="https://wandb.ai/michellewl/AQmortality/runs/rnwwb1ak" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/rnwwb1ak</a><br/>
#                 Run data is saved locally in <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112957-rnwwb1ak</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 447<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112957-rnwwb1ak/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/users/mwlw3/AQmortality/wandb/run-20210604_112957-rnwwb1ak/logs/debug-internal.log</code>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">legendary-water-270</strong>: <a href="https://wandb.ai/michellewl/AQmortality/runs/rnwwb1ak" target="_blank">https://wandb.ai/michellewl/AQmortality/runs/rnwwb1ak</a><br/>

# %%
income_df.shape
# Out:
# (7671, 1)

# %%
plt.figure(figsize=(5,4), dpi=300)
income_df["income"].plot()
plt.ylabel("Gross disposable income per capita (£)")
plt.suptitle("London regional median income")
plt.show()

# %% [markdown]
# #### Scatter plot mortality vs disposable income

# %%
income_df = income_df.join(mortality_df)

# %%
plt.figure(figsize=(5,4), dpi=300)
plt.hexbin(income_df.income, income_df.deaths_per_100k, cmap=cm.plasma, gridsize=100, mincnt=1)
plt.ylabel("daily deaths per 100,000")
plt.xlabel("gross disposable income per capita (£)")
plt.title("London mortality vs median income")
plt.colorbar().set_label("counts")
plt.show()

# %% [markdown]
# ## Time series decomposition: trends

# %% [markdown]
# **Trends** represent how the variable is changing overall through time.
# **Seasonality** shows how the variable changes within a given period e.g. year, month.
# **Residual** activity is not explained by the trend or seasonality.
#
# Additive model:
# `y(t) = Trend(t) + Seasonality(t) + Residual(t)`
#
# Multiplicative model:
# `y(t) = Trend(t) * Seasonality(t) * Residual(t)`

# %% [markdown]
# #### Mortality data

# %% [markdown]
# Here we use the `seasonal_decompose()` function with an additive model. Note that we have to manually set `period` (for filtering) to `365`, because otherwise the function by default looks for weekly (`period=7`) trends when given daily data (inferred from the `DatetimeIndex`).

# %%
decomp = tsa.seasonal_decompose(mortality_df["deaths_per_100k"], model="additive", period=365)
decomp_df = pd.DataFrame({"observed":decomp.observed, "trend":decomp.trend, "seasonal":decomp.seasonal, "residual":decomp.resid})

plt.figure(figsize=(5,4), dpi=300)
decomp_df["observed"].plot()
decomp_df["trend"].plot()
plt.legend()
plt.ylabel("deaths per 100,000")
plt.suptitle("London mortality")
plt.show()

plt.figure(figsize=(5,4), dpi=300)
decomp_df.loc[decomp_df.index.year>2010]["seasonal"].plot()
plt.ylabel("Seasonal variation in deaths per 100,000")
plt.suptitle("Seasonal variation: London mortality")
plt.show()

# %% [markdown]
# #### NO$_2$ data

# %%
decomp = tsa.seasonal_decompose(daily_df["mean_NO2"], model="additive", period=365)
decomp_df = pd.DataFrame({"observed":decomp.observed, "trend":decomp.trend, "seasonal":decomp.seasonal, "residual":decomp.resid})

plt.figure(figsize=(5,4), dpi=300)
decomp_df["observed"].plot()
decomp_df["trend"].plot()
plt.legend()
plt.ylabel("mean daily NO$_2$ (µg m$^{-3}$)")
plt.suptitle("London daily NO$_2$")
plt.show()

plt.figure(figsize=(5,4), dpi=300)
decomp_df.loc[decomp_df.index.year>2010]["seasonal"].plot()
plt.ylabel("Seasonal variation in daily NO$_2$ (µg m$^{-3}$)")
plt.suptitle("Seasonal variation: London NO$_2$")
plt.show()

# %% [markdown]
# #### Temperature data

# %%
decomp = tsa.seasonal_decompose(daily_df.dropna()["temperature"], model="additive", period=365)
decomp_df = pd.DataFrame({"observed":decomp.observed, "trend":decomp.trend, "seasonal":decomp.seasonal, "residual":decomp.resid})

plt.figure(figsize=(5,4), dpi=300)
decomp_df["observed"].plot()
decomp_df["trend"].plot()
plt.legend()
plt.ylabel("mean daily temperature (℃)")
plt.suptitle("London daily temperature")
plt.show()

plt.figure(figsize=(5,4), dpi=300)
decomp_df.loc[decomp_df.index.year>2010]["seasonal"].plot()
plt.ylabel("Seasonal variation in daily temperature (℃)")
plt.suptitle("Seasonal variation: London temperature")
plt.show()

# %% [markdown]
# #### Disposable income data

# %%
decomp = tsa.seasonal_decompose(mortality_df["deaths_per_100k"], model="additive", period=365)
decomp_df = pd.DataFrame(income_df["income"]).join(pd.DataFrame({"mortality_trend":decomp.trend}))

# decomp_df["income"].plot(label="income").set_ylabel("mean daily disposable income (£)")
# decomp_df["mortality_trend"].plot(label="mortality").set_ylabel("mortality trend")
# plt.twinx()
# plt.legend()
# plt.ylabel("mean daily disposable income (£)")
# plt.suptitle("London disposable income")
# plt.show()

fig, ax = plt.subplots(figsize=(6,4), dpi=300)
#fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()

p1, = ax.plot(decomp_df.index, decomp_df["income"],"tab:blue", label="median income")
p2, = twin1.plot(decomp_df.index, decomp_df["mortality_trend"], "tab:orange", label="mortality trend (excludes seasonality)")

ax.set_xlabel("Date")
ax.set_ylabel("gross disposable income per capita (£)")
twin1.set_ylabel("deaths per 100,000")

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())

tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)

plt.legend(handles=[p1, p2])
plt.suptitle("London mortality and median income")

plt.show()

# %%
plt.figure(figsize=(5,4), dpi=300)
plt.hexbin(decomp_df.income, decomp_df.mortality_trend, cmap=cm.plasma, gridsize=30, mincnt=1)
plt.ylabel("daily deaths per 100,000")
plt.xlabel("gross disposable income per capita (£)")
plt.title("London mortality trend vs median income")
plt.colorbar().set_label("counts")
plt.show()
